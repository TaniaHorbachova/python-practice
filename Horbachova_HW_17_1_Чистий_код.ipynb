# %% [markdown]
# У завданнях 1-4. Вам наданий простий код на Python, який не відповідає вказівкам PEP8. Ваше завдання — відредагувати код так, аби він відповідав PEP8. Напишіть після редагуванню коду, дотримання яких правил з pep8 ви досягли в відредагованій версі, наприклад
# ```
# - додала пробіли навколо бінарного оператора
# - додала два порожні рядки між визначеннями функцій
# і тд
# ```
# Також можна зазанчити використані правила коментарями по коду, а не окремим повідомленням.
#
# Відредагований код має виконувати весь той самий функціонал, але бути написаний відповідно до вимог до гарного коду на Python! Не забудьте запустити відредагований код, він має бути робочим.

# %% [markdown]
# **Завдання 1.**

# %%
def greet(name):print(f"Hello, {name}")
def add(n1,n2):return n1+n2

x = 5;y = 3
display(greet("John"),add(x,y))

# %% [markdown]
# **Відредагований код:**

# %%
def greet(name):
    """
    Виводить привітання з ім'ям
    """
    print(f"Hello, {name}")


def add(n1, n2):
    """
    Повертає суму двох чисел
    """
    return n1 + n2

x = 5
y = 3

print(greet("John"))
print(add(x, y))
# Out:
# Hello, John
# None
# 8

# %% [markdown]
# **Правила PEP8, що були застосовані:**
# 1. Додала docstring для кожної функції.
# 2. Перенесла інструкцію print(f"Hello, {name}") всередині тіла функції на новий рядок з відступом у 4 пробіли.
# 3. Додала два порожні рядки між визначенням першої і другої функцій.
# 4. Додала пробіл між аргументами функції add.
# 5. Перенесла інструкцію return n1+n2 всередині тіла функції на новий рядок з відступом у 4 пробіли.
# 6. Додала пробіли навколо оператора +.
# 7. Задала значення змінних в окремих рядках.
# 8. Використала print замість display, бо display не є стандартною функцією Python.
# 9. Додала пробіл між аргументами функції add при виводі результату.

# %% [markdown]
# **Завдання 2.**

# %%
from math import *
def calcArea(r):return pi*r**2
def calcCircumference(r):return 2*pi*r

radius=5
print("Area:",calcArea(radius),"Circumference:",calcCircumference(radius))

# %% [markdown]
# **Відредагований код:**

# %%
from math import pi


def calc_area(r):
    """
    Обчислює площу кола за радіусом
    """
    return pi * r ** 2


def calc_circumference(r):
    """
    Обчислює довжину кола за радіусом
    """
    return 2 * pi * r


radius = 5

print("Area:", calc_area(radius), "Circumference:", calc_circumference(radius))
# Out:
# Area: 78.53981633974483 Circumference: 31.41592653589793

# %% [markdown]
# **Правила PEP8, що були застосовані:**
# 1. Імпортувала лише потрібне ім'я pi замість *from math import* *.
# 2. Додала по два порожні рядки між блоками імпорту, визначенням першої, визначенням другої функції.
# 3. Назви функцій змінила на нижній регістр з нижнім підкресленням (*calcArea на calc_area, calcCircumference на calc_circumference*).
# 4. Додала docstring для кожної функції.
# 5. Тіло кожної функції перенесла на новий рядок з відступом у 4 пробіли.
# 6. Додала пробіли навколо операторів *, **, =.
# 7. Додала порожній рядок між визначенням змінної та викликом результату для кращої читабельності.
# 8. Додала пробіли при вказуванні аргументів виводу результату.

# %% [markdown]
# **Завдання 3.**

# %%
class animal: pass
class dog(animal):
    def __init__(self,name):
        self.name=name
        self.type='Dog'

# %% [markdown]
# **Відредагований код:**

# %%
class Animal:
    """
    Базовий клас для тварин
    """
    pass


class Dog(Animal):
    """
    Клас для собаки, успадковує від Animal
    """

    def __init__(self, name):
        self.name = name
        self.type = "Dog"

# %% [markdown]
# **Правила PEP8, що були застосовані:**
# 1. Назви класів змінила у стилі CapWords: *animal* на *Animal*, *dog* на *Dog*.
# 2. Додала Docstring для класів для розуміння їх призначення.
# 3. Додала два порожні рядки між визначеннями класів.
# 4. Додала порожній рядок між класом і методом класу для кращої читабельності.
# 5. Додала пробіл між аргументами методу.
# 6. Тіла класів і методу перенесла на новий рядок з відступом у 4 пробіли.
# 7. Додала пробіли навколо оператора =.

# %% [markdown]
# **Завдання 4.**

# %%
list=[1,2,3,4,5]
for i in range(len(list)):print(list[i])

# %% [markdown]
# **Відредагований код:**

# %%
numbers = [1, 2, 3, 4, 5]

for number in numbers:
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **Правила PEP8, що були застосовані:**
# 1. Використала назву змінної numbers замість list, бо це є одне з зарезервованих слів.
# 2. Додала пробіли навколо оператора =.
# 3. Додала пробіли після коми в переліку значень у списку.
# 4. Додала порожній рядок між списком та циклом.
# 5. Переписала цикл на більш простий:  *for i in range(len(list))* на *for number in numbers*.
# 6. Тіло циклу перенесла на новий рядок з відступом у 4 пробіли.

# %% [markdown]
# **Завдання 5.** У вас є DataFrame df, що представляє результати тестів студентів з математики, англійської мови та історії. Поточний код обчислює середній бал для кожного студента шляхом ітерації за рядками DataFrame за допомогою iterrows().
#
# Ваше завдання полягає в тому, щоб змінити код так, аби уникнути використання iterrows() і замість цього застосувати більш ефективне та читабельне рішення відповідно до правил, озвучених у лекції. Рефакторинг треба зробити лише частині, де рахуються середні, імпорт і визначення датафрейму лишаємо без змін.

# %%
import pandas as pd

df = pd.DataFrame({
    'student': ['Alice', 'Bob', 'Charlie', 'David'],
    'math_score': [89, 94, 77, 85],
    'english_score': [92, 88, 79, 85],
    'history_score': [84, 92, 81, 89]
})

# %%
averages = []
for _, row in df.iterrows():
    averages.append((row['math_score'] + row['english_score'] + row['history_score']) / 3)

df['average_score'] = averages

# %% [markdown]
# **Рефакторінг:**

# %%
df['average_score'] = df[['math_score', 'english_score', 'history_score']].mean(axis=1).round(2)
print(df)
# Out:
#    student  math_score  english_score  history_score  average_score
# 0    Alice          89             92             84          88.33
# 1      Bob          94             88             92          91.33
# 2  Charlie          77             79             81          79.00
# 3    David          85             85             89          86.33

# %% [markdown]
# **Висновок:** завдяки векторизаціїї код зрозуміліший, коротший і працює швидше.

# %% [markdown]
# **Завдання 6.** У Вас є великий DataFrame df, що представляє транзакції продажу в магазині. Цей DataFrame містить понад 1 мільйон рядків і кілька стовпців, зокрема «product_name», «product_category», «product_price» і «transaction_date».
#
# І «product_name», і «product_category» є рядками, що представляють численні, але обмежені унікальні назви продуктів і категорії відповідно.
#
# Напишіть код для ефективного перетворення стовпців «product_name» і «product_category» на категорійний тип для ефективного використання пам’яті.
# Спробуйте вирішити це завдання, мінімізуючи використання пам'яті та зберігаючи читабельність коду. Крім того, виміряйте використання пам’яті до та після перетворення, щоб продемонструвати підвищення ефективності.
#
# Порівняйте кількість памʼяті, яку займає наданий набір даних і новий, створений Вами. В лекції був приклад. В скільки разів менше памʼяті займає новий датафрейм?

# %%
import numpy as np

np.random.seed(0)

products = ['apple', 'banana', 'cherry', 'dates', 'elderberry']
categories = ['fruit', 'fruit', 'fruit', 'fruit', 'fruit']

N_ROWS = 10**6
df_products = pd.DataFrame({
    'product_name': np.random.choice(products, N_ROWS),
    'product_category': np.random.choice(categories, N_ROWS),
    'product_price': np.random.uniform(1, 10, N_ROWS),
    'transaction_date': pd.date_range(start='1/1/2000', periods=N_ROWS, freq='h')
})

memory_before = df_products.memory_usage(index=False).sum()
print(f"Використання пам'яті до перетворення: {memory_before:.2f} байт.")
# Out:
# Використання пам'яті до перетворення: 32000000.00 байт.

# %% [markdown]
# Перетворення рядкових стовпців на категорійний тип та кількість використаної пам'яті після оптимізації коду.

# %%
df_products['product_name'] = df_products['product_name'].astype('category')
df_products['product_category'] = df_products['product_category'].astype('category')

memory_after = df_products.memory_usage(index=False).sum()
print(f"Використання пам'яті після перетворення: {memory_after:.2f} байт.")

ratio = memory_before / memory_after
print(f"\nНовий DataFrame займає у {ratio:.1f} разів менше пам'яті.")
# Out:
# Використання пам'яті після перетворення: 18000328.00 байт.
#
# Новий DataFrame займає у 1.8 разів менше пам'яті.

# %% [markdown]
# **Висновок:**
#
# 1. Так як в попередньому завданні вже була імпортована бібліотека pandas, то в цьому завданні я прибрала її імпорт.
# 2. Також в попередньому завданні вже була таблиця df, тому я перейменувала її на df_products.
# 3. Після перетворення рядкових стовпців на категорійний тип, кількість використаної пам'яті зменшилась майже вдвічі.

# %% [markdown]
# **Завдання 7.** В цьому завданні кілька пунктів. Треба виконати усі послідовно.
#     7.1. Завантажте дані у pandas dataframe з файла `ecommerce_data.csv`. Обовʼязково при завантаженні вкажіть параметр `encoding = 'ISO-8859-1'`, без нього буде помилка.
#     7.2. Заповніть пропущені значення в колонці CustomerID на -1 та перетворіть тип цієї колонки на str, адже зараз вона типу float, а це не правильний тип даних для ідентифікатора клієнта.
#     7.3. З допомогою бібліотеки sweetviz побудуйте html звіт, який порівнює дані для країни "Germany" і країни "France". У Вас можуть виникнути багато попереджень (Warning), їх рекомендую вимкнути наступним шматком коду
#
#
#     import warnings
#
#     with warnings.catch_warnings(record=True):
#         # your code
#
#
#    7.4.Напишіть 5 відмінностей для двох зазначених країн на основі побудованого звіту, без виконання додаткового аналізу іншими інструментами.

# %% [markdown]
# **7.1. Завантаження даних**

# %%
data = pd.read_csv('D:/DATAS/Python/data/Модуль 17/ecommerce_data.csv', encoding='ISO-8859-1')
data.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# **7.2. Заповнення пропусків у колонці CustomerID та зміна типу даних**

# %%
data['CustomerID'] = data['CustomerID'].fillna(-1).astype(str)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   541909 non-null  object
#  7   Country      541909 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 33.1+ MB

# %% [markdown]
# **7.3. Створення html-звіту з допомогою бібліотеки sweetviz**

# %%
import warnings
import sweetviz as sv

# Monkey patch для сумісності бібліотеки Sweetviz з новими версіями numpy, бо все одно видавало помилку
np.VisibleDeprecationWarning = Warning

with warnings.catch_warnings():
    report = sv.compare(
        [data[data['Country'] == "Germany"], "Germany"],
        [data[data['Country'] == "France"], "France"]
    )
    report.show_html("report_germany_france.html")
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report report_germany_france.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# **7.4. Відмінності між Німеччиною та Францією (на основі звіту sweetviz):**
#
# 1. Кількість транзакцій:
# - Німеччина має 9495 записів, а Франція - 8557, це означає, що активність покупців у Німеччині вища.
#
# 2. Кількість унікальних замовлень та клієнтів. Німеччина демонструє більшу різноманітність бази як по замовленням, так і по клієнтам:
# - у Німеччині 603 унікальних інвойси проти 461 у Франції.
# - у Німеччині зареєстровано 95 унікальних клієнтів, тоді як у Франції - 88.
#
# 3. Обсяги закупівлі товару. Французькі замовлення більші за розміром в одиницях товару:
# - максимальна кількість - у Франції було замовлено 912 одиниць одного товару, а у Німеччині максимум - 600.
# - середня кількість одиниць у замовленні у Франції трохи вища - 13 проти 12 у Німеччині.
#
# 4. Ціни на товари. Франція купує значно дорожчі одиничні товари:
# - максимальна ціна - найдорожчий товар, куплений у Франції коштував 4161, тоді як у Німеччині - 600.
# - варіативність цін у Франції дуже сильно відрізняється - 6385, порівняно з Німеччиною - 274, що свідчить про наявність дуже дорогих ексклюзивних позицій у французьких чеках.
#
# 5. Сумарна виручка. В Німеччині більше транзакцій, але Франція приносить більше грошей за рахунок вищих цін:
# - загальна сума за колонкою ціни у Франції становить 43 032, тоді як у Німеччині — 37 666.
# - Німеччина лідирує за загальною кількістю проданих одиниць товару - 117 тис. проти 110 тис. у Франції, але Франція краща у грошовому еквіваленті.
#
# **Висновок:**
# Німеччина - країна з великою кількістю дрібних і стабільних замовлень від більшої кількості клієнтів. У Франції - ринок з меншою кількістю замовлень, але з набагато вищим середнім чеком та закупівлею дуже дорогих товарів.

# %% [markdown]
# **Завдання 8.** З допомогою ChatGPT виявіть, чи є та які помилки в наступному коді.
# Попросіть після цього переписати код із дотриманням PEP8. Проаналізуйте результат. Чи справді ChatGPT виправив всі стилістичні помилки? Якщо ні, напишіть йому ще кілька запитів, аби код відповідав вимогам PEP8.
# Вставте фінальну версію коду з чату у ноутбук та запустіть на заданому списку. Має вертатись 50.
# Напишіть, які промпти (інструкції) при зверненні до ChatGPT ви застосували та додайте скріншот(-и) з промптами та відповідями чата.
# Якщо зробили висновки при виконанні цього завдання, то діліться також :)
#
# **ЯК ВСТАВИТИ СКРІНШОТ в Jupyter Notebook** :
# 1. Створіть нову Markdown клітинку
# 2. В новоствореній клітинці обираєте в меню Jupyter Notebook Edit -> Insert Image
# 3. Обираєте картинку
# 4. В клітинці має зʼявитись текст, який містить картинку. Запустіть клітинку.
#
# Або можна просто перетягнути картинку в Markdown клітинку.

# %%
def CalculateVariance(nl):
    sum_list = 0
    for n in nl:
        sum_list = sum_list + n
    mean = sum_list / len(nl)
    sum_squares = 0
    for n in nl:
        sum_squares = sum_squares + n**2
    mean_squares = sum_squares / len(nl)
    return mean_squares

# %%
input_list = [75, 80, 85, 90, 95]

# %% [markdown]
# **Відредагований код:**

# %%
def calculate_variance(numbers):
    """
    Обчислює дисперсію для чисел у списку
    """
    if not numbers:
        raise ValueError('Список чисел не може бути порожнім.')

    mean = sum(numbers) / len(numbers)
    return sum((x - mean) ** 2 for x in numbers) / len(numbers)

# %%
result = calculate_variance(input_list)
print(result)
# Out:
# 50.0

# %% [markdown]
# **Правила PEP8, що були застосовані:**
#
# 1. Змінила назву функції на нижній регістр з підкресленням.
# 2. Додала docstring для функції.
# 3. Задала зрозумілу назву параметру.
# 4. Використала sum замість циклу.
# 5. Додала перевірку на порожній список.
# 6. Додала обчислення справжньої дисперсії.
#
# **Висновок:**
# ChatGPT допоміг не просто виправити стилістичні помилки коду для відповідності PEP8, а ще й знайшов та виправив логічну помилку прорахунку саме дисперсії, яку я не зрозуміла.

# %% [markdown]
# ![image.png](attachment:6bec2ae1-73ed-450a-9a6c-f4ce10df4775.png)

# %% [markdown]
# ![image.png](attachment:ac59932a-224a-4acf-8f69-e9e7b5222f70.png)

# %% [markdown]
# ![image.png](attachment:3f4fdd03-b125-41f0-93df-ac44df2124a0.png)

# %% [markdown]
# ![image.png](attachment:0cafef8f-f98a-4e56-8723-ed23be857e46.png)

# %% [markdown]
# ![image.png](attachment:fe701de8-83bb-4483-b6e5-9e086f2b59a7.png)

# %% [markdown]
# ![image.png](attachment:dd5f8733-7fbd-4504-a6f6-2a976345a998.png)

# %% [markdown]
# ![image.png](attachment:d503e49a-8654-4c33-bafc-a4655169a559.png)

# %% [markdown]
# ![image.png](attachment:0db93cd6-f163-4d56-8f96-52b93a05f895.png)
